 7.865709616967401,-4.46048155699302,-1.3570490012376957,6.5425194353698455,-8.341304615919446,
 5.752130001202128,-0.08278612363409138,-5.709650548338964,8.561641982583614,-6.923865966263566,
 1.6021652338894832,4.637309471034498,-8.506189462351873,7.927407282271141,-3.1500539128887963,
 -3.352679351137899,8.163936230406483,-8.719037064765669,4.6726241906845924,1.8916691979024318,
 -7.5340015424556,9.261292052072799,-6.115144190457997,-0.2978095852826337,6.625895571041086,
 -9.52445711468088,7.423929783466559,-1.3791379996348347,-5.4594184067657965,9.48781130087668,
 -8.548291409367499,3.0848139629539255,4.064195655830474,-9.140578784542141]

# %%
plt.figure(figsize=(20,20))

# Erick Juárez (UNAM)

plt.subplot(581) # numbered by row, col, order
plt.plot(Vthu_x, Vthu_y, color="aqua") # plot data and color
plt.fill(Vthu_x, Vthu_y, color="indigo", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vthu_x, Vthu_y, color="orangered", s=200, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#Alejandra Barrios Flores (UNAM)
plt.subplot(582)
plt.plot(Vrup_x, Vrup_y, color="blue") # plot data and color
plt.fill(Vrup_x, Vrup_y, color="gray", alpha=0.4) # fill data and color and alpha (transparency)
plt.scatter(Vrup_x, Vrup_y, color="olivedrab", s=200, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# Vitis piasezkii, Paige Durant (MSU)
plt.subplot(583)
plt.plot(Vpia_x, Vpia_y, color = "#10A83B", linewidth = 3, linestyle = 'dotted') # plot data and color
plt.fill(Vpia_x, Vpia_y, color = "#C2E812", alpha = 0.9) # fill data and color and alpha (transparency)
plt.scatter(Vpia_x, Vpia_y, color="#FF934F", s=200, alpha=0.7) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# Vitis aestivalis, Joshua Temple (MSU)

plt.subplot(584)
plt.plot(Vaes_x, Vaes_y, c="cyan", lw=30, alpha=0.3)
plt.fill(Vaes_x, Vaes_y, c="orchid", alpha=0.4)
plt.scatter(Vaes_x, Vaes_y, color="purple", s=20, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

# my grapevine leaf plot, Dan Dick (MSU)

plt.subplot(585)
plt.plot(Vaes_x, Vaes_y, color="darkgreen") # plot data and color
plt.fill(Vaes_x, Vaes_y, color="gray", alpha=0.8) # fill data and color and alpha (transparency)
plt.scatter(Vaes_x, Vaes_y, color="orange", s=150, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Zhuohao Li (MSU)
plt.subplot(586)
plt.plot(Vpal_x, Vpal_y, color="blue") 
plt.fill(Vpal_x, Vpal_y, color="black", alpha=0.5) 
plt.scatter(Vpal_x, Vpal_y, color="green", s=300, alpha=0.6) 
plt.gca().set_aspect('equal', adjustable="datalim") 
plt.axis('off')

#My grapevine leafs, Diego Zubillaga Martin(UNAM)
plt.subplot(587)
plt.plot(Vaes_x, Vaes_y, color="#581845")
plt.fill(Vaes_x, Vaes_y, color="#4EEFB7", alpha=0.6)
plt.scatter(Vaes_x, Vaes_y, color="limegreen", s=150, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

#My grapevine leafs, Diego Zubillaga Martin(UNAM)
plt.subplot(588)
plt.plot(Vpal_x, Vpal_y, color="k")
plt.fill(Vpal_x, Vpal_y, color="gold", alpha=0.6)
plt.scatter(Vpal_x, Vpal_y, color="peru", s=150, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

#My grapevine leafs, Diego Zubillaga Martin(UNAM)
plt.subplot(589)
plt.plot(Abre_x, Abre_y, color="pink")
plt.fill(Abre_x, Abre_y, color="brown", alpha=0.6)
plt.scatter(Abre_x, Abre_y, color="purple", s=150, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

#My grapevine leafs, Diego Zubillaga Martin(UNAM)
plt.subplot(5,8,10)
plt.plot(Acor_x, Acor_y, color="orange")
plt.fill(Acor_x, Acor_y, color="green", alpha=0.6)
plt.scatter(Acor_x, Acor_y, color="yellow", s=150, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

# my grapevine leaf, Diana Villarreal Huerta (UNAM)
plt.subplot(5,8,11)
plt.plot(Vrup_x, Vrup_y, color="lightcoral", linewidth=10, alpha=0.5) # plot data and color
plt.fill(Vrup_x, Vrup_y, color="black", alpha=0.9) # fill data and color and alpha (transparency)
plt.scatter(Vrup_x, Vrup_y, color="cyan", s=200, alpha=0.3) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grapevinge leaf, Nick Moreno (MSU)
plt.subplot(5,8,12)
plt.plot(Vrup_x, Vrup_y, color="teal") #plot data and color
plt.fill(Vrup_x, Vrup_y, color="gray", alpha=0.9) #fill data and color and alpha
plt.scatter(Vrup_x, Vrup_y, color="limegreen", s=100, alpha=0.6) #point data, color, size, and alpha
plt.gca().set_aspect("equal", adjustable="datalim") #set equal axes
plt.axis('off') #axes off

# my grapevine leaf, Jud Van Wyk (MSU)
plt.subplot(5,8,13)
plt.plot(Vthu_x, Vthu_y, color="limegreen") # plot data and color
plt.fill(Vthu_x, Vthu_y, color="darkgreen", alpha= 0.9) # fill data and color and alpha (transparency)
plt.scatter(Vthu_x, Vthu_y, color="green", s=10, alpha=0.9) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Oscar Pérez Flores (UNAM)
plt.subplot(5,8,14)
plt.plot(Vpia_x, Vpia_y, color="gold") # plot data and color
plt.fill(Vpia_x, Vpia_y, color="greenyellow", alpha=0.4) # fill data and color and alpha
plt.scatter(Vpia_x, Vpia_y, color="yellow", s=300, alpha=0.6) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Karina Astudillo (UNAM)
plt.subplot(5,8,15)
plt.plot(Vlab_x, Vlab_y, color="#CF4021", linestyle=":", linewidth=2) 
plt.scatter(Vlab_x, Vlab_y, color="k", s=100)
plt.fill(Vlab_x, Vlab_y, color="#CF2185", alpha=0.5)
plt.gca().set_aspect("equal", "datalim")
plt.axis('off') 

# my grapevine leaf, Julia Zheng (MSU)
plt.subplot(5,8,16)
plt.plot(Vvul_x , Vvul_y , color="#bdbdbd") # plot data and color
plt.fill(Vvul_x , Vvul_y , color="#e7e1ef", alpha=0.8) # fill data and color and alpha (transparency)
plt.scatter(Vvul_x , Vvul_y , color="#ece7f2", s=200, alpha=0.8) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Elizabeth Barrera Sánchez (UNAM)
plt.subplot(5,8,17)
plt.plot(Abre_x, Abre_y, color="royalblue") # plot data and color
plt.fill(Abre_x, Abre_y, color="seagreen", alpha=0.4) # fill data and color and alpha (transparency)
plt.scatter(Abre_x, Abre_y, color="green", s=400, alpha=0.7) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Juliana Hanle (MSU)
plt.subplot(5,8,18)
plt.plot(Vcoi_x, Vcoi_y, color="grey", alpha=.1) # plot data and color
plt.fill(Vcoi_x, Vcoi_y, color="honeydew", alpha=0.9) # fill data and color and alpha (transparency)
plt.scatter(Vcoi_x, Vcoi_y, color="crimson", s=40, alpha=1) # point data, color, size, and alpha
plt.scatter(Vcoi_x, Vcoi_y, color="lightgreen", s=40, alpha=0.4) # point data, color, size, and alpha
plt.scatter(Vcoi_x, Vcoi_y, color="yellow", s=10, alpha=0.4) # point data, color, size, and alpha
plt.scatter(Vcoi_x, Vcoi_y, color="antiquewhite", s=20, alpha=0.4) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, John Hawkins (MSU
plt.subplot(5,8,19)
plt.plot(Vlab_x, Vlab_y)
plt.scatter(Vlab_x, Vlab_y, color="blue", s=100)
plt.fill(Vlab_x, Vlab_y, color="blue", alpha=0.5)
plt.plot(Vrip_x, Vrip_y, color="yellow")
plt.scatter(Vrip_x, Vrip_y, color="yellow", s=100)
plt.fill(Vrip_x, Vrip_y, color="yellow", alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Santiago Garcia Rios (UNAM)
plt.subplot(5,8,20)
plt.plot(Aaco_x, Aaco_y, color="darkviolet", linestyle="solid", linewidth=3)
plt.scatter(Aaco_x, Aaco_y, color="darkorange", s=200)
plt.fill(Aaco_x, Aaco_y, color='#42A84F', alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

#my grapevine leaf, Patrick López (UNAM)
Vvul_x_half = [0.5 * i for i in Vvul_x]
Vvul_y_half = [0.5 * i for i in Vvul_y]
Vvul_x_half1 = [0.7 * i for i in Vvul_x]
Vvul_y_half1 = [0.7 * i for i in Vvul_y]
Vvul_x_half2 = [0.9 * i for i in Vvul_x]
Vvul_y_half2 = [0.9 * i for i in Vvul_y]
plt.subplot(5,8,21)
plt.plot(Vvul_x,Vvul_y, linewidth=2, color = "gold")
plt.fill(Vvul_x,Vvul_y, color = "darkgreen")
plt.fill(Vvul_x_half2, Vvul_y_half2, color = "green" )
plt.fill(Vvul_x_half1, Vvul_y_half1, color = "forestgreen" )
plt.fill(Vvul_x_half, Vvul_y_half, color = "lightgreen" )
plt.scatter(Vvul_x_half2, Vvul_y_half2, color = "yellow", marker="|" )
plt.scatter(Vvul_x_half1, Vvul_y_half1, color = "yellow",marker ="4" )
plt.scatter(Vvul_x_half, Vvul_y_half, color = "yellow", marker ="3" )
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grapevine leaf, Eduardo Pineda (UNAM)
plt.subplot(5,8,22)
plt.plot(Vpal_x, Vpal_y,color = "green", linestyle=":",  linewidth=7)
plt.scatter(Vpal_x, Vpal_y, )
plt.fill(Vpal_x, Vpal_y, color="#cd853f", alpha=.8)
plt.gca().set_aspect("equal", "datalim")
plt.axis("off")

# my grapevine leaf, Carlos (UNAM)

plt.subplot(5,8,23)
plt.plot(Vvul_x, Vvul_y, color="#5F00B8") 
plt.fill(Vvul_x, Vvul_y, color="#4BCC00", alpha=0.2) 
plt.scatter(Vvul_x, Vvul_y, color="#5F00B8", s=200, alpha=0.8)
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off')

# my grapevine leaf, Mariana Luna (UNAM)
plt.subplot(5,8,24)
plt.plot(Vrip_x, Vrip_y, color="yellow", linewidth = 2, linestyle = 'dotted' ) # plot data and color
plt.fill(Vrip_x, Vrip_y, color="limegreen", alpha=0.7) # fill data and color and alpha (transparency)
plt.scatter(Vrip_x, Vrip_y, color="pink", s=200, alpha=0.8) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off
   
#My grapevine leaf, Valeria Flores (UNAM)

plt.subplot(5,8,25)
plt.plot(Abre_x, Abre_y, color="green") # plot data and color
plt.fill(Abre_x, Abre_y, color="green", alpha=0.3) # fill data and color and alpha (transparency)
plt.scatter(Abre_x, Abre_y, color="darkslateblue", s=100, alpha=0.8) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Jim Lennon (MSU)
def get_spiral():
# Source: https://matplotlib.org/stable/gallery/misc/fill_spiral.html
    import numpy as np
    theta = np.arange(0, 8*np.pi, 0.1)
    
    a = 2
    b = .2

    for dt in np.arange(0, 2*np.pi, np.pi/4.0):
        x = a*np.cos(theta + dt)*np.exp(b*theta)
        y = a*np.sin(theta + dt)*np.exp(b*theta)

        dt = dt + np.pi/4.0

        x2 = a*np.cos(theta + dt)*np.exp(b*theta)
        y2 = a*np.sin(theta + dt)*np.exp(b*theta)

        xf = np.concatenate((x, x2[::-1]))
        yf = np.concatenate((y, y2[::-1]))

    return xf, yf

# my MSU grapevine leaf, Jim Lennon (MSU)
plt.subplot(5,8,26)
MSU_green = '#18453B'
plt.fill(Abre_x, Abre_y, color=MSU_green)
xf, yf = get_spiral()
plt.fill(xf, yf, color='white')
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my grapevine leaf, Ben Dolgikh (MSU)
plt.subplot(5,8,27)
plt.plot(Vcoi_x, Vcoi_y, color="purple") # plot data and color
plt.fill(Vcoi_x, Vcoi_y, color="limegreen", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vcoi_x, Vcoi_y, color="lightblue", s=200, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grapevine leaf, Connor Purvis (MSU)
plt.subplot(5,8,28)
plt.plot(Vaes_x, Vaes_y, color = "black", linestyle = "solid", linewidth = "2")
plt.scatter(Vaes_x, Vaes_y, color = "gray", s=80)
plt.fill(Vaes_x, Vaes_y, color = "lavenderblush", alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

#my grapevine leaf, Deborah Espinosa (UNAM)
plt.subplot(5,8,29)
plt.plot(Vthu_x, Vthu_y, color="c")
plt.fill(Vthu_x, Vthu_y, color="#8856a7", alpha=0.5)
plt.scatter(Vthu_x, Vthu_y, color="yellow", s=200, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

# grape plot, Farnaz Tajik (MSU)
plt.subplot(5,8,30)
plt.plot(Vace_x, Vace_y, color="green") 
plt.fill(Vace_x, Vace_y, color="black", alpha=0.1) 
plt.scatter(Vace_x, Vace_y, color="navy", s=50, alpha=0.1)
plt.gca().set_aspect('equal', adjustable="datalim") 
plt.axis('off')

# grape plot, Farnaz Tajik (MSU)       
plt.subplot(5,8,31)
plt.plot(Vvul_x, Vvul_y, color="slateblue") 
plt.fill(Vvul_x, Vvul_y, color="tan", alpha=0.1) 
plt.scatter(Vvul_x, Vvul_y, color="navy", s=50, alpha=0.1)
plt.gca().set_aspect('equal', adjustable="datalim") 
plt.axis('off')

# my grapevine leaf, Manica (UB)
plt.subplot(5,8,32)
plt.plot(Vrup_x, Vrup_y, color="lightblue") # plot data and color
plt.plot(Aaco_x, Aaco_y, color="orchid") # plot data and color
plt.fill(Vrup_x, Vrup_y, color="lightblue", alpha=0.4)
plt.fill(Aaco_x, Aaco_y, color="orchid", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vrup_x, Vrup_y, color="lightblue", s=100) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="box") # set equal axes
plt.axis('off') # axes off

# my sunflower leaf, Jill Check (MSU)
plt.subplot(5,8,33)
plt.plot(Vcin_x, Vcin_y, color="#5F264E", alpha = 0.5, linewidth = 5) # plot data and color
plt.fill(Vcin_x, Vcin_y, color="#3F6435", alpha=0.65) # fill data and color and alpha (transparency)
plt.scatter(Vcin_x, Vcin_y, color="k", s=1000, marker = '$cinerea$') # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off
   
# my grapevine leaf, Antonio Cuenca Mejía (UAEMex)
plt.subplot(5,8,34)
plt.plot(Vpia_x, Vpia_y, color="#F91616", linestyle= "dashdot")
plt.fill(Vpia_x, Vpia_y, color="#AC1F01", alpha= 0.1)
plt.scatter(Vpia_x, Vpia_y, color="#7E330D", s=10, alpha=1.0) 
plt.gca().set_aspect("equal", "datalim")
plt.axis('off') # axes off

#my grape Lourdes
plt.subplot(5,8,35)
plt.plot(Vrup_x, Vrup_y, color="honeydew") # plot data and color
plt.fill(Vrup_x, Vrup_y, color="olivedrab", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vrup_x, Vrup_y, color="limegreen", s=100, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grape Lourdes
plt.subplot(5,8,36)
plt.plot(Vthu_x, Vthu_y, color="tomato") # plot data and color
plt.fill(Vthu_x, Vthu_y, color="darksalmon", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vthu_x, Vthu_y, color="mistyrose", s=200, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grape Lourdes
plt.subplot(5,8,37)
plt.plot(Vvul_x, Vvul_y, color="darkcyan") # plot data and color
plt.fill(Vvul_x, Vvul_y, color="cyan", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vvul_x, Vvul_y, color="steelblue", s=200, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my grape Lourdes
plt.subplot(5,8,38)
plt.plot(Vpia_x, Vpia_y, color="blue") # plot data and color
plt.fill(Vpia_x, Vpia_y, color="slateblue", alpha=0.5) # fill data and color and alpha (transparency)
plt.scatter(Vpia_x, Vpia_y, color="mediumorchid", s=300, alpha=0.5) # point data, color, size, and alpha
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#My grapeleaf Chloe (MSU)
plt.subplot(5,8,39)
plt.plot(Vlab_x, Vlab_y, color="black", linestyle='--', linewidth=2,)
plt.scatter(Vlab_x, Vlab_y, color="purple", s=500, marker='p')
plt.fill(Vlab_x, Vlab_y, color="darkgreen", alpha=.5)
plt.gca().set_aspect('equal', adjustable="box") # set equal axes
plt.axis('off') # axes off

#My grapevine leafs, Diego Zubillaga Martin(UNAM)
plt.subplot(5,8,40)
plt.plot(Abre_x, Abre_y, color="pink")
plt.fill(Abre_x, Abre_y, color="brown", alpha=0.6)
plt.scatter(Abre_x, Abre_y, color="purple", s=150, alpha=0.5)
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

plt.savefig("grapevine_leaves.jpg")

# %%
plt.figure(figsize=(20,20))

# my grapevine leaf, Jill Check (MSU)
plt.subplot(481)
plt.scatter(sun_xlist, sun_ylist, s=50, alpha=0.75, c='k', marker = '*')
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=150, alpha=0.6, c="#1FF1F8", marker = '*')
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=150, alpha=0.6, c="#FF00DC", marker = '*')
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#Alejandra Barrios Flores (UNAM)
plt.subplot(482)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::13], sun_ylist[::13], s=50, alpha=0.6, c="darkblue")
plt.scatter(sun_xlist[::34], sun_ylist[::34], s=60, alpha=0.6, c="purple")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Paige Durant (MSU)
plt.subplot(483)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=1, c="#FFF1D0")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=40, alpha=0.5, c="#DD1C1A")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=60, alpha=0.5, c="#F0C808")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=80, alpha=0.5, c="#DD1C1A")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=100, alpha=0.5, c="#F0C808")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# sunflower, Joshua Temple (MSU)
idx1 = 2
idx2 = 2
idx3 = 1
plt.subplot(484)
plt.scatter(np.array(sun_xlist[::idx1])*0.9, np.array(sun_ylist[::idx1])*0.9, c='hotpink',alpha=0.3, s=2000, marker='D')
plt.scatter(np.array(sun_xlist[::idx2])*0.8,np.array(sun_ylist[::idx2])*0.8, c='purple', alpha=0.3, s=3000, marker='o')
plt.scatter(np.array(sun_xlist[::idx3])*1.0, np.array(sun_ylist[::idx3])*1.0, c='purple', alpha=0.2, s=2000)
plt.scatter(np.array(sun_xlist[::idx3])*0.5, np.array(sun_ylist[::idx3])*0.5, c='red', alpha=0.1, s=2000)
plt.scatter(np.array(sun_xlist[::idx2])*1.0, np.array(sun_ylist[::idx2])*1.0, c='cyan', alpha=0.1, s=2000)
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Dan Dick (MSU)

plt.subplot(485)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=50, alpha=0.6, c="grey")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=0.6, c="green")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Zhuohao Li (MSU)
plt.subplot(486)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="b")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=50, alpha=0.6, c="black")
plt.scatter(sun_xlist[::10], sun_ylist[::10], s=60, alpha=0.6, c="orange")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') 

#My sunflower plot, Diego Zubillaga Martin (UNAM)
plt.subplot(487)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.fill(sun_xlist, sun_ylist, alpha=0.1, c="green")
plt.scatter(sun_xlist[::4], sun_ylist[::4], s=50, alpha=0.6, c="k")
plt.plot(sun_xlist[::4], sun_ylist[::4], alpha=0.4, c="yellow")
plt.scatter(sun_xlist[::8], sun_ylist[::8], alpha=0.5, c="orange")
plt.plot(sun_xlist[::8], sun_ylist[::8], alpha=0.6, c="brown")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Diana Villarreal Huerta (UNAM)
plt.subplot(488)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, color="aquamarine")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=30, alpha=0.4, c="slategray")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=0.6, c="cornflowerblue")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#my sunflower plot, Nick Moreno (MSU)
plt.subplot(489)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="gray")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=50, alpha=0.6, c="orange")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=60, alpha=0.6, c="purple")
plt.scatter(sun_xlist[::13], sun_ylist[::13], s=70, alpha=0.6, c="green")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Jud Van Wyk (MSU)
plt.subplot(4,8,10)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::1], sun_ylist[::1], s=500, alpha=0.6, c="yellow")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=200, alpha=0.6, c="k")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower, Jim Lennon (MSU)
def get_spiral():
    # Source: https://matplotlib.org/stable/gallery/misc/fill_spiral.html
    import numpy as np
    theta = np.arange(0, 8*np.pi, 0.1)
    a = 2
    b = .2

    for dt in np.arange(0, 2*np.pi, np.pi/4.0):
        x = a*np.cos(theta + dt)*np.exp(b*theta)
        y = a*np.sin(theta + dt)*np.exp(b*theta)

        dt = dt + np.pi/4.0

        x2 = a*np.cos(theta + dt)*np.exp(b*theta)
        y2 = a*np.sin(theta + dt)*np.exp(b*theta)

        xf = np.concatenate((x, x2[::-1]))
        yf = np.concatenate((y, y2[::-1]))

    return xf, yf

# my UNAM sunflower plot, Jim Lennon (MSU)
plt.subplot(4,8,11)
UNAM_blue = '#062953'
UNAM_yellow = '#C49646'
plt.scatter(sun_xlist, sun_ylist, s=60, c=UNAM_blue, alpha=0.3)
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=80, c=UNAM_blue, alpha=0.9)
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=30, c=UNAM_blue, alpha=0.7)
plt.fill(sun_xlist, sun_ylist, color=UNAM_yellow, alpha=0.4)
xf, yf = get_spiral()
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Oscar Pérez Flores (UNAM)
plt.subplot(4,8,12)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="pink")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=50, alpha=0.5, c="orchid")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=40, alpha=0.5, c="magenta")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Karina Astudillo (UNAM)
plt.subplot(4,8,13)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=50, alpha=0.6, c="pink")
plt.scatter(sun_xlist[::7], sun_ylist[::7], s=60, alpha=0.6, c="blue")
plt.gca().set_aspect('equal', adjustable="datalim") 
plt.axis('off') 

 # my sunflower plot, Julia Zheng (MSU)
plt.subplot(4,8,14)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.6, c="#fee0d2")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=50, alpha=0.7, c="#fec44f")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=60, alpha=0.7, c="#e6550d")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off
         
 # my sunflower plot, Elizabeth Barrera Sánchez (UNAM)
plt.subplot(4,8,15)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=50, alpha=0.6, c="orange")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=40, alpha=0.6, c="tomato")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower leaf, Juliana Hanle (MSU)
plt.subplot(4,8,16)
plt.scatter(sun_xlist, sun_ylist, s=2, alpha=0.8, c="dodgerblue")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=35, alpha=0.5, c="darkblue")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=65, alpha=0.5, c="lightpink")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=65, alpha=0.5, c="aliceblue")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Santiago Garcia Rios (UNAM)
plt.subplot(4,8,17)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::3], sun_ylist[::3], color="purple", linewidth=0.3, alpha=1)
plt.scatter(sun_xlist[::5], sun_ylist[::5], color="blue", linewidth=0.3, alpha=1)
plt.gca().set_aspect('equal', 'datalim')
plt.axis('off')

#my sunflower, Eduardo Pineda (UNAM)
plt.subplot(4,8,18)
plt.fill(sun_xlist[::5], sun_ylist[::5], color="pink", alpha=0.5)
plt.scatter(sun_xlist[::5], sun_ylist[::5], color="red", alpha=.7)
plt.scatter(sun_xlist[::5], sun_ylist[::5], color="blue", alpha=.7)
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off')

# my sunflower plot, Carlos (UNAM)

plt.subplot(4,8,19)
plt.plot(sun_xlist, sun_ylist, color="yellow", alpha =0.3)
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=50, alpha=1, c="#3F681C")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=60, alpha=1, c="#FFBB00")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=1, c="#FB6542")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=60, alpha=1, c="#9B4F0F")
plt.scatter(sun_xlist[::13], sun_ylist[::13], s=60, alpha=1, c="#F52549")
plt.axis('off')

# my sunflower plot, Mariana Luna (UNAM)
plt.subplot(4,8,20)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="blue")
plt.scatter(sun_xlist[::4], sun_ylist[::4], s=50, alpha=0.6, c="yellow")
plt.scatter(sun_xlist[::10], sun_ylist[::10], s=60, alpha=0.6, c="red")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

#My sunflower leaf, Valeria Flores (UNAM)
plt.subplot(4,8,21)
plt.plot(sun_xlist, sun_ylist, color="gold")
plt.scatter(sun_xlist, sun_ylist, s=50, alpha=0.5, color= "red")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Ben Dolgikh (MSU)
plt.subplot(4,8,22)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.3, c="b")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=50, alpha=0.6, c="gold")
plt.scatter(sun_xlist[::9], sun_ylist[::9], s=60, alpha=0.8, c="silver")
plt.gca().set_aspect('equal', 'box') # set equal axes
plt.axis('off') # axes off

# my sunflower plot, John Hawkins (MSU
plt.subplot(4,8,23)
plt.plot(sun_xlist, sun_ylist, color="yellow")
plt.scatter(sun_xlist[::5], sun_ylist[::5], color="red")
plt.scatter(sun_xlist[::8], sun_ylist[::8], color="blue")
plt.scatter(sun_xlist[::13], sun_ylist[::13], color="green")
plt.gca().set_aspect('equal', 'box') # set equal axes
plt.axis('off') # axes off
         
# my sunflower plot, Connor Purvis (MSU)
plt.subplot(4,8,24)
plt.plot(sun_xlist, sun_ylist, color="black", alpha=0.1)
plt.scatter(sun_xlist, sun_ylist, s=10, color="cadetblue", alpha=0.5)
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=30, alpha=1, c="purple")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=50, alpha=1, c="salmon")
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off') # axes off

# My sunflower plot, Deborah Espinosa(UNAM)
plt.subplot(4,8,25)
plt.fill(sun_xlist, sun_ylist,color="#8856a7", alpha=0.5)
plt.plot(sun_xlist, sun_ylist, linestyle=":", linewidth=2)
plt.scatter(sun_xlist, sun_ylist, s=30, alpha=0.3, c="c")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=50, alpha=0.6, c="coral")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=0.6, c="magenta")
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')

 # my sunflower plot, Farnaz Tajik(MSU)
plt.subplot(4,8,26)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="olive")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=50, alpha=0.4, c="orangered")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=60, alpha=0.8, c="crimson")
plt.gca().set_aspect('equal', adjustable="datalim") 
plt.axis('off') 

# my sunflower plot, Manica (UB)
plt.subplot(4,8,27)
plt.plot(sun_xlist, sun_ylist, color="k", alpha=0.1)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::10], sun_ylist[::10], s=50, alpha=0.8, c="lightskyblue")
plt.scatter(sun_xlist[::9], sun_ylist[::9], s=60, alpha=0.8, c="thistle")
plt.scatter(sun_xlist[::7], sun_ylist[::7], s=60, alpha=0.8, c="deepskyblue")
plt.scatter(sun_xlist[::6], sun_ylist[::6], s=60, alpha=0.8, c="violet")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=0.8, c="steelblue")
plt.scatter(sun_xlist[::4], sun_ylist[::4], s=60, alpha=0.8, c="mediumorchid")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=60, alpha=0.8, c="dodgerblue")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off
         

#My sunflower Chloe (MSU)
plt.subplot(4,8,28)
plt.scatter(sun_xlist, sun_ylist, s=100, c="mediumslateblue", marker='p')
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=100, alpha=1, c="darkorchid", marker='h')
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=100, alpha=1, c="palevioletred")
plt.plot(sun_xlist, sun_ylist, alpha=0.50, color="pink", linestyle=":")
plt.plot(sun_xlist[::5], sun_ylist[::5], color="pink")
plt.plot(sun_xlist[::8], sun_ylist[::8], color="lightblue")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') 

#my sunflower plot, Antonio Cuenca Mejía (UAEMex)
plt.subplot(4,8,29)
plt.scatter(sun_xlist, sun_ylist,s=40, alpha=0.1, c= "k")
plt.scatter(sun_xlist[::9], sun_ylist[::9], s=60, alpha=0.6, c= "limegreen")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=40, alpha=1, c= "red")
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off')     

# sunflower Lourdes
plt.subplot(4,8,30)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=0.1, c="k")
plt.scatter(sun_xlist[::13], sun_ylist[::13], s=50, alpha=0.6, c="#876705")
plt.scatter(sun_xlist[8::5], sun_ylist[8::5], s=60, alpha=0.6, c="#e377c2")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

# my sunflower plot, Patrick López  (UNAM)
plt.subplot(4,8,31)
plt.fill(sun_xlist, sun_ylist, alpha=0.3,c="gold")
plt.scatter(sun_xlist[::1], sun_ylist[::1], s=30, alpha=1, c="pink", marker = "D")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=30, alpha=1, c="red", marker= "X")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=60, alpha=1, c="darkgrey", marker="o")
plt.gca().set_aspect('equal', adjustable="datalim")
plt.axis('off') # axes off    

# my sunflower plot, Paige Durant (MSU)
plt.subplot(4,8,32)
plt.scatter(sun_xlist, sun_ylist, s=40, alpha=1, c="#FFF1D0")
plt.scatter(sun_xlist[::2], sun_ylist[::2], s=40, alpha=0.5, c="#DD1C1A")
plt.scatter(sun_xlist[::3], sun_ylist[::3], s=60, alpha=0.5, c="#F0C808")
plt.scatter(sun_xlist[::5], sun_ylist[::5], s=80, alpha=0.5, c="#DD1C1A")
plt.scatter(sun_xlist[::8], sun_ylist[::8], s=100, alpha=0.5, c="#F0C808")
plt.gca().set_aspect('equal', adjustable="datalim") # set equal axes
plt.axis('off') # axes off

plt.savefig("sunflowers.jpg")
